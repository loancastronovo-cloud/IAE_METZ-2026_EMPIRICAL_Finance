# %% [markdown]
# # Premiers exercices

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule de code 
#Python est une Programmation orienté OBJECT. on def des varaibles
name="Ajla"

name
# Out:
# 'Ajla'

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %%
name= "Thomas"
name 
# la dernière def de variable l'emporte
# Out:
# 'Thomas'

# %%
# Pour les chiffres on a 
age = 26 
print(age) # INTEGRER donc les nombres entiers
# Out:
# 26

# %%
pi= 3.14159
pi
# Out:
# 3.14159

# %%
# un dictionnaire c est CLE VALEUR
prices = {
    "APPL":2
}
